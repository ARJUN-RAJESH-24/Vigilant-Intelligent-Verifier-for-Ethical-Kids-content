# %%
# 02_feature_extraction.ipynb

import os
from IPython.display import display
import pandas as pd

# Run the scripts directly (assuming in 'notebooks' folder)
os.system("python ../scripts/extract_text_features.py")
os.system("python ../scripts/extract_audio_features.py")
os.system("python ../scripts/extract_video_features.py")

# Display outputs
print("\n✅ Feature extraction complete! Displaying extracted features...\n")

text_feats = pd.read_csv("../features/text_features.csv")
audio_feats = pd.read_csv("../features/audio_features.csv")
video_feats = pd.read_csv("../features/video_features.csv")

display(text_feats.head())
display(audio_feats.head())
display(video_feats.head())
